# %%
# Import modules
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('funda-amsterdam.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                         address  area  bedrooms postal_code  \
# 0           0       Knollendamstraat 4 III/IV   108         2     1013 TN
# 1           1             Moerdijkstraat 47 1    47         1     1079 XM
# 2           2               Zeeburgerdijk 349   116         2     1095 AD
# 3           3          Brederodestraat 124 -1    58         2     1054 VH
# 4           4  Admiraal De Ruijterweg 409 III    63         1     1055 MD
#
#   posting_date   price property_type  rooms  sale_date  \
# 0     4-6-2016  510000     apartment      3  23-6-2016
# 1    22-6-2016  215000     apartment      2   5-7-2016
# 2     9-6-2016  325000     apartment      3   8-7-2016
# 3    14-5-2016  315000     apartment      3   2-6-2016
# 4    14-6-2016  200000     apartment      3  23-6-2016
#
#                                                  url  year_built
# 0  http://www.funda.nl/koop/verkocht/amsterdam/ap...        1906
# ...

# %%
df1 = df[(df['price'] > 30000) & (df['area'] > 10)]
df_two_variables = df1[['price', 'area']]

# %%
sns.regplot(x='area', y='price', fit_reg=False, data=df_two_variables)
plt.show()

# %%
sns.regplot(x='area', y='price', fit_reg=True, data=df_two_variables)
plt.show()

# %%
x = df_two_variables[['area']] #to use sk-learn, we need to create lists of the two variables
y = df_two_variables['price']

lm = LinearRegression() #this creates a new LR model
lm.fit(x, y) #this "fits" the model

b0 = lm.intercept_ #gets the intercept
b1 = lm.coef_[0] #lm.coef_ gets a list of coefficients (excluding the intercept). [0] gets the actual number from the list

print(f"The regression line is equal to y = {b0:.2f} + {b1:.2f}X") #.0f formats to 2 decimals.
# Out:
# The regression line is equal to y = 27983.93 + 3498.81X

# %%
df['price_p'] = lm.predict(x) #use built-in predict() method to generate predictions; store in original dataframe
df.head(50)
# Out:
# /Users/Shayan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#     Unnamed: 0                                address  area  bedrooms  \
# 0            0              Knollendamstraat 4 III/IV   108         2
# 1            1                    Moerdijkstraat 47 1    47         1
# 2            2                      Zeeburgerdijk 349   116         2
# 3            3                 Brederodestraat 124 -1    58         2
# 4            4         Admiraal De Ruijterweg 409 III    63         1
# 5            5              Bertrand Russellstraat 46   125         2
# 6            6           Admiraal De Ruijterweg 417 I    64         3
# ...

# %%
df[df['address']=='Diopter 10'].head()
# Out:
#     Unnamed: 0     address  area  bedrooms postal_code posting_date   price  \
# 47          47  Diopter 10   135         4     1025 MS    18-5-2016  349000
#
#    property_type  rooms  sale_date  \
# 47         house      6  13-6-2016
#
#                                                   url  year_built  \
# 47  http://www.funda.nl/koop/verkocht/amsterdam/hu...        1998
#
#           price_p
# 47  500323.868478
